# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
import os

agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    )
)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# [{'type': 'text', 'text': 'The moon does not have a capital because it is not a country, nor does it have a government, cities, or permanent inhabitants. \n\nUnder the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no nation can claim sovereignty over the moon or any other celestial body. Therefore, there are no political borders or administrative centers.', 'extras': {'signature': 'EnEKbwFpFH0TdGehd74yOCBCGbxm/kHwh8e5i+RhpfwCW4hbNiUV3Y87rb5lpgcNEKMnFN6v+1JYGJhGSdf/XPT9N0MYu3sXtzWBHc5+T56k6P0O4kEmsllbpca0sghXt7P8f9uNwANGHrVuzPwVlT0+Ag=='}}]

# %%
from langchain.chat_models import init_chat_model
import os
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    ),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# [{'type': 'text', 'text': 'The capital of the Moon is **Artemis Prime**, though the locals—those born in the low-gravity silence of the lunar surface—call it **"The Silver Basin."**\n\nHere is a glimpse into the city:\n\n### The Architecture: "The Inverted Spire"\nArtemis Prime is not built upon the surface; it is carved deep into the basalt walls of the **Shackleton Crater** at the lunar South Pole. Because of the Moon’s lack of atmosphere, the city is crowned by a massive, semi-transparent dome of reinforced graphene-glass that glitters like a jagged diamond against the permanent blackness of the lunar sky.\n\nThe city is structured vertically. At the center hangs the **Inverted Spire**, a colossal architectural marvel that dangles from the crater’s rim. It houses the administrative hubs and the "Central Gravity Well," which uses centrifugal force to provide simulated Earth-normal gravity for visiting diplomats and planetary officials.\n\n### The Atmosphere\nThe streets of Artemis Prime are perpetually bathed in a soft, synthetic amber light designed to mimic a constant Earth-sunset. Because the city lies in a region of "Eternal Light," the exterior towers are covered in solar-collection filaments that pulse with rhythmic blue light, channeling energy to the colonies spread across the dark side of the Moon.\n\n### The Culture: "Dust-Born"\nTo live in Artemis Prime is to live in a world of extreme efficiency and fragile containment. The citizens, known as *Lunarians*, are easily identified by their height—they grow tall and lean due to the low gravity, and they possess a unique, fluid way of moving that makes Earth-dwellers look like they are wading through molasses. \n\nFashion is dictated by utility. Most citizens wear "haptic-skins"—tight, shimmering suits that monitor oxygen levels and pressure. On formal occasions, the elite layer these with cloaks woven from synthetic lunar silk, which refracts the harsh starlight of the vacuum.\n\n### The Political Climate\nArtemis Prime serves as the legislative center for the **Lunar Hegemony**. It is a city of cold diplomacy. Because the city sits atop the vast water-ice reserves at the South Pole, it holds a monopoly on the fuel trade for the entire solar system. \n\nThe air in the capital is thin, filtered to perfection, and smells faintly of ozone and recycled water. It is a quiet city. Without wind or rain, the only sounds are the hum of air scrubbers and the soft *thrum-thrum* of the mag-lev transit pods moving through the subterranean tunnels.\n\n### Why you’d want to go:\nIf you stand on the Observation Deck of the Inverted Spire at "midnight," you can look up through the dome and see Earth—not as a map or a photo, but as a marble of swirling blue and white, hanging perfectly still in the void. It is the only place in the solar system where you can watch the world that birthed you, while standing on a world that chose to survive without it.', 'extras': {'signature': 'EnEKbwFpFH0Tb90UaBEaCWN2eNR0IRIddePLz1eJvm/QkubPkTr0S6PkyvKWoADfriUYf4HASFDotXiRl3OEzE5geNXszSR0ocB0xOdLKz3o5xfea6PY21/J89Xf50i3h2L3ZWD0rP9ZvVEBxrFSaVQiWw=='}}]

# %% [markdown]
# ## Few-shot examples

# %%
from langchain.chat_models import init_chat_model
import os
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    ),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# [{'type': 'text', 'text': 'Scifi Writer: Selenopolis', 'extras': {'signature': 'EnEKbwFpFH0TRO2nrJrUzq4CaEGL1B3vFqldd0GDibmvVMLvb6YE+y/q1r7uqnp/HuedPZRA/saGYLTLItk/lBsAcwRyublru7H2QfYpq7oPFN59mUiE1x0p9iFvwW+x9Ke7Ox22CVj/1jCRhSMA69EuYw=='}}]

# %% [markdown]
# ## Structured prompts

# %%
from langchain.chat_models import init_chat_model
import os
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    ),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# [{'type': 'text', 'text': '**Name:** Selene Prime\n\n**Location:** Located within the Shackleton Crater at the lunar south pole, built into the subterranean lava tubes beneath the crater floor.\n\n**Vibe:** Industrial-chic, subterranean, ethereal.\n\n**Economy:** Helium-3 extraction, deep-space refueling logistics, and low-gravity pharmaceutical manufacturing.', 'extras': {'signature': 'EnEKbwFpFH0TGErl89MDT2aGjrLeqKTN/nrUwOyR5arp8wRf3ZsHsE2RetlikpmQ7zlXLf4vqUMOhiacA+WhupQ8aSxRvWqpf1TEE8HKfn0+EXzf/sx2z3WoQEEj9yzMhjdMX1crqsEQRkaSuLjR1pVCYg=='}}]

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
from pydantic import BaseModel
import os

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    ),
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='The Shackleton Crater, Lunar South Pole', vibe='Brutalist crystalline elegance characterized by perpetual Earth-light and deep subterranean silence', economy='Extraction of Helium-3 and high-end orbital manufacturing research')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at The Shackleton Crater, Lunar South Pole
