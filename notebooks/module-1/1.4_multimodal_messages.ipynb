# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
import os

model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google-genai",
    api_key=os.getenv("GOOGLE_API_KEY"),
)

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [{'type': 'text', 'text': 'The capital of the Moon is **Artemis Prime**, a subterranean marvel located beneath the floor of the Shackleton Crater at the lunar south pole.\n\n### The City Structure\nArtemis Prime is not a city of skyscrapers, but of "geodesic honeycombs." Because the surface is plagued by extreme thermal fluctuations and lethal cosmic radiation, the city is carved directly into the basaltic rock of the crater’s depths.\n\nThe city is structured in concentric rings:\n*   **The Core (The Hearth):** A massive, pressurized atrium built around a central fusion reactor. It features a holographic projection of an Earth-style sky, complete with a simulated sun cycle to help colonists maintain circadian rhythms.\n*   **The Mid-Levels (The Spines):** Vertical shafts filled with modular housing units, hydroponic vertical farms, and research laboratories. Gravity in these areas is supplemented by localized centrifuge rings, though most residents have adapted to the native 1/6th gravity by wearing weighted "anchor-suits."\n*   **The Rim (The Docks):** Situated at the crater’s edge, where the "Peaks of Eternal Light" provide near-constant solar energy. This is where the massive electromagnetic mass-drivers launch cargo shuttles to Earth’s orbit and receive raw materials mined from the lunar mantle.\n\n### The Atmosphere\nThe air in Artemis Prime smells faintly of ozone and pulverized rock—a byproduct of the oxygen-scrubbers that constantly work to recycle the thin, synthetic air. Because water is the most precious commodity, the city operates on a 99.8% closed-loop recycling system; every drop of perspiration and waste is reclaimed.\n\n### Politics and Culture\nArtemis Prime is governed by the **Lunar Council**, a technocratic body composed of lead engineers, planetary geologists, and the Chief Administrator of Life Support. \n\nLife on the moon has created a unique subculture known as "Lunarians." They are known for their distinct lanky physiology and a cultural obsession with silence—due to the acoustic sensitivity of the pressurized pressurized tunnels, loud noises are considered both rude and a potential safety hazard. Fashion consists of "skinsuits" made of smart-fabrics that regulate body temperature and monitor biometric vitals, usually decorated with bioluminescent patches to signify one\'s trade guild or family lineage.\n\n### The "Ghost-Side"\nWhile Artemis Prime is the bustling, bright capital, the locals often speak in hushed tones of the "Ghost-Side"—the dark, unpressurized tunnels of old 21st-century lunar outposts that were abandoned during the Great De-escalation. Explorers often trek into these silent, frozen ruins to scavenge historical artifacts, treating them like cathedrals of a forgotten age.\n\n**Coordinates:** 89.9°S, 0.0°E (Deep within the Shackleton shadow-shield).', 'extras': {'signature': 'EnEKbwFpFH0TYrxgX0ntC1nDT5Doe9T8Kx9l80sOl009Zh8ANmjtGOOdAw/0/BhOaHsGhAXTTSmSb9MFB4W3yLHSE3F8gUYRCVEb6HIkm3fWAnrzitoaRl+0hmUCbGFfwF2N32JIEUVJN/7LNT2mXbqENw=='}}]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'vangogh.png', 'type': 'image/png', 'size': 1549183, 'content': <memory at 0x7f32a06519c0>, 'last_modified': datetime.datetime(2026, 9, 2, 2, 41, 2, 576000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [{'type': 'text', 'text': 'The city is called **Aethelgard-Prime**, the final terrestrial anchor point of a civilization that transcended the need for linear time. \n\nWhat you see in the sky is not a natural firmament, but the **Luminous Web**—an atmospheric energy grid designed to keep the planet’s shifting reality from dissolving into the void of the multiverse. The great, towering spire in the foreground is the **Singularity Spire**, the only structure on the planet capable of anchoring a physical form. It is fashioned from carbon-lattice obsidian, acting as a lightning rod for the raw chronological radiation that pours down from the nebula-clouds above.\n\n### Life in Aethelgard-Prime\nThe citizens here do not live in houses as we understand them. Because the city exists within a high-gravity distortion field, the architecture is constantly "flowing." The buildings look as though they are painted in permanent motion, their materials caught in a viscous, never-ending state of growth and erosion. \n\nIf you look closely at the streets, you won\'t see roads; you see veins of bioluminescent light. The inhabitants move by harmonizing their personal frequency with the city\'s hum, effectively "sliding" through the architecture. \n\n### The Great Mystery\nThe massive yellow orb—the **Crescent Core**—is not a moon. It is the city’s heart, a captive sun contained within a magnetic suspension field. It provides the city with infinite energy, but it comes at a price: the light it emits is sentient. It watches. It records every thought, every movement, and every flicker of existence within its sight.\n\nTo live in Aethelgard-Prime is to live inside a masterpiece of cosmic engineering. It is beautiful, yes, but it is also a place of profound solitude. There is no night here, only the swirling, rhythmic turbulence of time itself, glowing in shades of midnight blue and electric gold. \n\nIt is the capital of a thousand civilizations that died elsewhere, a museum of existence where nothing ever truly ends—it just rotates into the next swirl of the sky.', 'extras': {'signature': 'EnEKbwFpFH0T9g0xPiDsYk38MdQHaw0JA4v5oCEcbyc5PJA7nTIzFAdHI+sQlwNdPkNsjJi8UpPqC0FEFGuAUTueNrBcimJzkR5F6VX9Pie5FnZxvrp0ObefXtpIMiUUZ0/V4MsrGXYpO5msexcDdOzfXw=='}}]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# ## Audio input

# %%
from ipywidgets import FileUpload
from IPython.display import display

audio_uploader = FileUpload(accept='.wav', multiple=False)
display(audio_uploader)
# Out:
# FileUpload(value=(), accept='.wav', description='Upload')

# %%
import base64

uploaded_audio = list(audio_uploader.value)
aud_bytes = bytes(uploaded_audio[0]["content"])
aud_b64 = base64.b64encode(aud_bytes).decode("utf-8")

agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# [{'type': 'text', 'text': 'The audio file contains the sound of someone shaking a small container filled with small objects, like beads or pebbles.', 'extras': {'signature': 'EnEKbwFpFH0TmeL5bmKf7cN6GC2HsJnChdFJ/hlXDAO6KGFU4bZFFTjcbzIl9MDOTEzMx3Im+YpIy/Mq7tWW3UODS8ks8aU+1kL5kyqv66BDUBuD5THVGeQaj2UXaLps96nDxp0P7OF3UT9GEnFAKB/3mA=='}}]
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
