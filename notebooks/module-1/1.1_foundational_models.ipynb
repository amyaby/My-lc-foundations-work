# %% [markdown]
# ### dotenv
# A tiny library that loads your .env file into the environment so you can read keys with os.getenv(). Purpose: never hardcode secrets in code.

# %%
from pathlib import Path
from dotenv import load_dotenv

load_dotenv("/home/im_ane/lca-lc-foundations/.env")
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model
import os

model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google-genai",
    #temperature =1
)

# %% [markdown]
# ### Invoke
# The model takes messages as input and outputs messages after generating a complete response.

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, cities, or sovereign population. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are various research stations and planned lunar bases in development (such as the proposed Artemis Base Camp), these are international or private scientific outposts rather than geopolitical capitals.', 'extras': {'signature': 'EnEKbwFpFH0Tz2NA+qT9jK76ZJv1QUBoqjd+i2J2fFjS7MNcXt/Drd2X7/ax0/bOETXRQ7bOeb0/A8tUMcZzfzkS6uqPmTpyKQ4wYvAUZSOp34QLlDLgEtoOfHgBQm1O/w3ouZVesUZv1fh6Dh4buDPpbw=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b9cc-d88e-7563-90f7-178441ea091f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 93, 'total_tokens': 103, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, cities, or sovereign population. Under the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are various research stations and planned lunar bases in development (such as the proposed Artemis Base Camp), these are international or private scientific outposts rather than geopolitical capitals.', 'extras': {'signature': 'EnEKbwFpFH0Tz2NA+qT9jK76ZJv1QUBoqjd+i2J2fFjS7MNcXt/Drd2X7/ax0/bOETXRQ7bOeb0/A8tUMcZzfzkS6uqPmTpyKQ4wYvAUZSOp34QLlDLgEtoOfHgBQm1O/w3ouZVesUZv1fh6Dh4buDPpbw=='}}]

# %% [markdown]
# ### System Prompt — steering the model before the question
#
# A `SystemMessage` sets the model's persona/rules *before* the user's question.
# Same question, totally different answer — that's what a system prompt controls.

# %%
from langchain.messages import SystemMessage, HumanMessage

# Without a system prompt — plain default LLM
plain = model.invoke("What's the capital of the Moon?")
print("NO SYSTEM PROMPT :", plain.text)

# With a system prompt — forces a personality + rules
with_system = model.invoke(
    [
        SystemMessage(
            "You are a cheerful pirate. Speak in pirate dialect and end every answer with 'Arrr!'."
        ),
        HumanMessage("What's the capital of the Moon?"),
    ]
)
print("WITH SYSTEM PROMPT:", with_system.text)
# Out:
# NO SYSTEM PROMPT : The Moon does not have a capital because it has no government, no countries, and no permanent human residents. It is considered an international territory under the **Outer Space Treaty of 1967**, which states that no nation can claim sovereignty over the Moon or any other celestial body.
# WITH SYSTEM PROMPT: Shiver me timbers, ye salty sea dog! The Moon be a barren rock floatin' in the dark sea of space, so she don't have no capital city nor a governor to keep the peace! 'Tis naught but craters and dust up there, fit only for stars to shine upon. Arrr!

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    )
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='ecb2c9ac-f215-4d92-bbce-a2ba282c387b'),
#               AIMessage(content=[{'type': 'text', 'text': 'The Moon does not have a capital city because it is not a country, nor is it governed by any single nation.\n\nAccording to the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body. As a result, there are no governments, political borders, or administrative capitals on the lunar surface.\n\nWhile there are several research bases and landing sites planned or currently in operation (like those established by China, the U.S., and other nations), they are scientific outposts rather than cities or political capitals.', 'extras': {'signature': 'EnEKbwFpFH0Tz0gz5K370j806ZxwhVI337FrlrIAHGy6aWGya0HrUP1Dvq7YV/3VeEuR+ioUmoSmtOL927LNA/QMOAcqvt049b7zxFkj7mu/0/DOf3XMZ0RdDOaF9/5+Aur53yxlwP5xIF/8CfjpewW/DA=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b9cc-e949-7563-97ba-75928d3755d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 128, 'total_tokens': 138, 'input_token_details': {'cache_read': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital city because it is not a country, nor is it governed by any single nation.\n\nAccording to the **Outer Space Treaty of 1967**, which has been signed by all major spacefaring nations, no country can claim sovereignty over the Moon or any other celestial body. As a result, there are no governments, political borders, or administrative capitals on the lunar surface.\n\nWhile there are several research bases and landing sites planned or currently in operation (like those established by China, the U.S., and other nations), they are scientific outposts rather than cities or political capitals.', 'extras': {'signature': 'EnEKbwFpFH0Tz0gz5K370j806ZxwhVI337FrlrIAHGy6aWGya0HrUP1Dvq7YV/3VeEuR+ioUmoSmtOL927LNA/QMOAcqvt049b7zxFkj7mu/0/DOf3XMZ0RdDOaF9/5+Aur53yxlwP5xIF/8CfjpewW/DA=='}}]

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a4ac033c-c3f9-4e89-87af-6aaedb855fd7'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='53976b22-4d5d-413f-9ab3-ed4e42489d57', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='1405c1ad-256c-4a87-82cc-06099061d6ee'),
#               AIMessage(content=[{'type': 'text', 'text': 'It is important to clarify that **Luna City is a fictional location.** There is no actual city or government on the Moon, and under the international **Outer Space Treaty of 1967**, no nation can claim sovereignty over any part of the Moon.\n\nHowever, "Luna City" is a foundational concept in science fiction and futurism. Here is why it is so iconic:\n\n### 1. The Fictional Origin\nThe name "Luna City" was popularized by **Robert A. Heinlein** in his 1951 classic novel ***The Moon Is a Harsh Mistress***. In his story, Luna City is the primary settlement on the Moon, described as a sprawling underground colony where "Loonies" (the lunar inhabitants) live. It serves as the hub for lunar mining, agriculture, and eventually, the center of a revolution against Earth’s rule.\n\n### 2. The Real-Life "Luna City" (Lunar Base Alpha)\nWhile we don\'t have a capital city, space agencies like NASA (through the **Artemis program**), ESA, and China’s CNSA are currently planning permanent lunar bases. \n*   **The Artemis Base Camp:** NASA envisions a base near the Moon\'s South Pole. It wouldn\'t be a "city" in the traditional sense, but rather a collection of modular habitats, power arrays, and life-support systems designed to sustain a rotating crew.\n*   **Why the South Pole?** Future "Luna Cities" will likely be located at the South Pole because it receives near-constant sunlight (for solar power) and contains permanently shadowed craters where **water ice** is trapped. This ice is the "gold" of the Moon—it can be converted into drinking water, oxygen for breathing, and hydrogen for rocket fuel.\n\n### 3. How a Real "Luna City" Would Work\nIf humans were to build a true city on the Moon, it would look very different from a city on Earth:\n*   **Underground Living:** To protect residents from harsh solar radiation and micrometeorite impacts, the city would likely be built inside lava tubes (huge natural underground tunnels) or covered by several meters of lunar "regolith" (soil).\n*   **Closed-Loop Ecosystems:** Since you can\'t just open a window, the city would be a completely sealed environment where every drop of water and breath of air is recycled.\n*   **Lower Gravity:** Because the Moon has only 1/6th of Earth’s gravity, the architecture would be different—structures could be much taller and lighter, but the long-term health effects of low gravity on the human body remain a major hurdle.\n\n### 4. Cultural Legacy\nBecause of Heinlein and other sci-fi writers, "Luna City" has become the shorthand for the dream of human expansion into space. Today, organizations like the **Moon Village Association** work on the international cooperation needed to eventually turn that fiction into a reality.\n\n**In short:** If you visit the Moon today, you won’t find a capital city, but if you look at the progress of the Artemis missions, you are looking at the foundation of the very first "districts" of a future lunar civilization.', 'extras': {'signature': 'EnEKbwFpFH0TNMbMmsMjTLrpMTr/m/xFikrZlvy0+Gz+F64j5IQl70gg6fIWOaJaokFIi6nCQaEv4jM4Hyr9FCAX9qqbzFWrUkhnMjr0of6qg15EIuPy+jRkrnYgA41gjqg6TV4MAw6Ie7RSpifG7f0zyw=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0b9cc-f08f-7b73-a88e-21e2f3870377-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 29, 'output_tokens': 674, 'total_tokens': 703, 'input_token_details': {'cache_read': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# [{'type': 'text', 'text': 'To understand', 'index': 0}]
# [{'type': 'text', 'text': ' **Luna City**, it is important to distinguish between the legendary fictional location and the real', 'index': 0}]
# [{'type': 'text', 'text': '-world scientific vision of what a lunar capital might eventually look like.\n\n### 1. The Fictional "Luna City"\n', 'index': 0}]
# [{'type': 'text', 'text': 'In science fiction, Luna City is an archetype of lunar colonization. \n\n*   **Robert A. Heinlein’s *', 'index': 0}]
# [{'type': 'text', 'text': 'The Moon Is a Harsh Mistress*:** This is the most famous depiction. In this version, Luna City is built', 'index': 0}]
# [{'type': 'text', 'text': ' underground for protection against radiation and micrometeorites. It is a sprawling, bustling subterranean metropolis connected by tunnels. The culture', 'index': 0}]
# [{'type': 'text', 'text': ' is libertarian, gritty, and fiercely independent, characterized by the slogan "TANSTAAFL" (*There Ain\'t No', 'index': 0}]
# [{'type': 'text', 'text': ' Such Thing As A Free Lunch*).\n*   **Isaac Asimov’s *The Caves of Steel*:** Here', 'index': 0}]
# [{'type': 'text', 'text': ', the Moon is presented as a place of domes and underground living, where society has adapted to the scarcity of water and', 'index': 0}]
# [{'type': 'text', 'text': ' oxygen by creating a highly efficient, regulated environment.\n*   **General Tropes:** In fiction, Luna City is almost', 'index': 0}]
# [{'type': 'text', 'text': ' always depicted as having low-gravity sports (like 3D basketball), hydroponic gardens, and a society that values', 'index': 0}]
# [{'type': 'text', 'text': ' recycling above all else.\n\n---\n\n### 2. The Real-World "Luna City" (The Vision)\nAs of', 'index': 0}]
# [{'type': 'text', 'text': ' today, there is no "capital" of the Moon, as the 1967 Outer Space Treaty forbids any nation', 'index': 0}]
# [{'type': 'text', 'text': ' from claiming sovereignty over celestial bodies. However, NASA’s **Artemis Program** and the international **Lunar Gateway', 'index': 0}]
# [{'type': 'text', 'text': '** project are currently laying the groundwork for a permanent lunar settlement.\n\nIf a "Luna City" were to be built today based', 'index': 0}]
# [{'type': 'text', 'text': ' on current aerospace engineering, it would likely look like this:\n\n#### A. The Location: The Lunar South Pole\nNASA', 'index': 0}]
# [{'type': 'text', 'text': ' and other space agencies are targeting the **Shackleton Crater** at the lunar south pole. Why there?\n*   **Peak of', 'index': 0}]
# [{'type': 'text', 'text': ' Eternal Light:** The rims of the crater receive almost constant sunlight, perfect for solar power.\n*   **Water Ice:** The interior of', 'index': 0}]
# [{'type': 'text', 'text': ' the crater is in permanent shadow, hiding massive deposits of water ice that can be converted into drinking water, oxygen, and liquid hydrogen rocket', 'index': 0}]
# [{'type': 'text', 'text': ' fuel.\n\n#### B. The Architecture: "Regolith Shielding"\nYou won\'t see glass domes.', 'index': 0}]
# [{'type': 'text', 'text': ' They are too fragile and provide no protection from cosmic radiation. A real Luna City would likely be:\n*   **', 'index': 0}]
# [{'type': 'text', 'text': 'Inflatable Habitats:** Pressurized modules covered in several meters of **lunar regolith** (moon dirt). The', 'index': 0}]
# [{'type': 'text', 'text': ' dirt acts as a thick shield against solar flares and meteorites.\n*   **Lava Tubes:** Scientists are investigating natural,', 'index': 0}]
# [{'type': 'text', 'text': ' massive underground tunnels formed by ancient volcanic activity. A city built inside these tubes would be naturally protected from the extreme temperature swings of', 'index': 0}]
# [{'type': 'text', 'text': ' the lunar surface.\n\n#### C. The Economy: The "Cislunar Economy"\nA capital city needs an industry', 'index': 0}]
# [{'type': 'text', 'text': '. A real Luna City would likely function as:\n*   **A Refueling Station:** Serving as a "gas', 'index': 0}]
# [{'type': 'text', 'text': ' station" for missions heading to Mars or the outer solar system.\n*   **A Research Hub:** Hosting observatories (', 'index': 0}]
# [{'type': 'text', 'text': 'the Moon’s far side is the quietest place in the solar system for radio astronomy).\n*   **In-Situ', 'index': 0}]
# [{'type': 'text', 'text': ' Resource Utilization (ISRU):** Using 3D printing to turn moon dust into concrete, tools, and spare parts.\n\n', 'index': 0}]
# [{'type': 'text', 'text': '---\n\n### 3. Challenges of a Lunar Capital\nIf you were a resident of Luna City, your daily life would be defined', 'index': 0}]
# [{'type': 'text', 'text': ' by extreme constraints:\n*   **The Gravity Problem:** Humans evolved in 1G. We do not know the', 'index': 0}]
# [{'type': 'text', 'text': ' long-term effects of living in 1/6th gravity (Moon gravity) on bone density, muscle mass, and', 'index': 0}]
# [{'type': 'text', 'text': ' reproduction.\n*   **Dust Toxicity:** Lunar dust (regolith) is incredibly jagged and abrasive because there is no wind to weather', 'index': 0}]
# [{'type': 'text', 'text': ' it down. It is like breathing in glass shards and destroys mechanical seals. Luna City would require intense "airlocks and decontamination', 'index': 0}]
# [{'type': 'text', 'text': '" rituals.\n*   **Psychology:** Residents would deal with the "Earth-gazing" phenomenon—a mix', 'index': 0}]
# [{'type': 'text', 'text': ' of intense homesickness and the "Overview Effect" caused by seeing Earth as a small, fragile blue marble in the sky.', 'index': 0}]
# [{'type': 'text', 'text': '\n\n### Summary\nWhile Luna City remains a concept, the **Artemis Base Camp** is currently being planned as', 'index': 0}]
# [{'type': 'text', 'text': " the first step. It won't have the neon lights or the bustling street markets of sci-fi novels yet, but", 'index': 0}]
# [{'type': 'text', 'text': ' it will be the most advanced scientific outpost in human history—a place where people live, work, and manufacture using nothing', 'index': 0}]
# [{'type': 'text', 'text': ' but the resources found in the lunar soil.', 'index': 0}]
# [{'type': 'text', 'text': '', 'extras': {'signature': 'EnEKbwFpFH0TNf/hQOxdet4A3bFP3YoPWNI4k92cKyk066dOSPBGf7e12U7Xh4Bmhf6gSf1kdhFvQIdexS1yVjA5bmFUbYz1kAMkWK3bM9ac5qPvgpSqkpEDHHS9wLfur6BRvUqAlDifOpmK48ODf7kvlQ=='}, 'index': 0}]

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
import os

system_prompt = "You are a science fiction writer. Create a capital city at the user's request, full of imaginative detail."

scifi_agent = create_agent(
    init_chat_model(
        model="gemini-3.1-flash-lite",
        model_provider="google-genai",
        api_key=os.getenv("GOOGLE_API_KEY"),
    ),
    system_prompt=system_prompt,
)

response = scifi_agent.invoke(
    {"messages": [HumanMessage("Create the capital city of the Moon.")]}
)
print(response["messages"][-1].text)
# Out:
# The capital city of the Moon is **Selene Prime**, a sprawling, multi-layered marvel of engineering located deep within the **Shackleton Crater** at the lunar south pole. Because it is nestled within the crater’s rim, it sits in "Permanent Light"—a band of perpetual sunshine that powers the city’s massive solar arrays, while the crater floor remains a treasury of accessible water ice.
#
# Here is a glimpse into the architecture and life of Selene Prime:
#
# ### The Architecture: "The Pearl and the Web"
# Selene Prime does not look like a collection of metal boxes. It is constructed from **Lunar Glass**, a translucent, reinforced material forged from local regolith using solar-focusing mirrors.
#
# *   **The Canopy:** The city is shielded by a colossal, pressurized dome made of "Smart-Silk"—a self-healing, carbon-nanotube weave that filters harmful cosmic radiation while allowing the Earth’s blue-white glow to bathe the city in a constant, ghostly twilight.
# *   **The Spires:** From the crater floor, elegant, spiral towers reach upward toward the rim. These are not just housing; they are "Vertical Gardens." Because gravity is one-sixth of Earth’s, the flora grows in towering, vine-like structures that provide the city’s oxygen and organic recycling.
# *   **The Abyss:** The city’s industrial core is buried deep underground. Known as "The Root," it is a labyrinth of tunnels where automated mining units harvest water ice and rare Helium-3, which is then launched via electromagnetic mass-drivers to the orbital docks above.
#
# ### Life in the Low-G
# Life in Selene Prime is defined by the "Lunar Gait"—a fluid, leaping movement that the citizens have perfected.
#
# *   **Public Transit:** Instead of subways, the city utilizes **Mag-Lev Tether-Lines**. Citizens strap into lightweight gliders and "fly" across the crater, propelled by magnetic currents. It is common to see a student commuting to university by soaring three hundred feet above the city’s central plaza.
# *   **The Fashion:** Because of the lower gravity, clothing is sculptural and dramatic. Heavy fabrics are obsolete; citizens wear gossamer, multi-layered garments made of synthetic spider-silk that shift color based on their biometric state.
# *   **The Silence:** Outside the pressurized zones, the Moon is a world of absolute silence. Selene Prime keeps its atmospheric pressure high, but the city’s design incorporates "Acoustic Dampening Groves"—parks filled with specialized moss that absorbs the hum of the city, leaving an eerie, profound quiet that the residents cherish as a reminder of the Moon’s true nature.
#
# ### The Centerpiece: The Earth-Well
# At the exact center of the city sits the **Earth-Well**. It is a polished, obsidian-lined observatory deck that points directly at the Earth hanging in the black sky above. Here, you will find the "Reflections"—a group of poets and astronomers who spend their lives watching the blue planet’s weather patterns and light pollution, documenting the changes on the home world from the silent vantage of the lunar frontier.
#
# ### The Cultural Flavor
# The cuisine of Selene Prime is distinct. Since livestock is impossible, the diet is heavily hydroponic and myco-based. The delicacy of the city is **"Moon-Honey,"** a translucent, nutrient-rich syrup harvested from genetically modified lichen that thrives in the crater’s shadows. It is said that a glass of sparkling Moon-Honey, sipped while watching the Earthrise over the crater’s rim, is the most expensive experience in the solar system.
#
# ### The Dark Secret
# Despite its beauty, Selene Prime is a city of "The Exiles." Most citizens are third or fourth-generation lunar-born, and many possess bone density and lung capacity so different from humans on Earth that they could never visit the mother planet. They look at Earth not as a home, but as a glowing, forbidden artifact—beautiful, fragile, and utterly foreign.
