# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google-genai",
    api_key=os.getenv("GOOGLE_API_KEY"),
)

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from pathlib import Path
from langchain_community.utilities import SQLDatabase

# Anchor the DB path (VS Code kernel cwd != notebook folder).
_db = next((p for p in [
    Path("/home/im_ane/lca-lc-foundations/notebooks/module-2/resources/Chinook.db"),
    Path.cwd() / "notebooks" / "module-2" / "resources" / "Chinook.db",
    Path.cwd() / "resources" / "Chinook.db",
] if p.exists()), None)
if _db is None:
    raise FileNotFoundError("Chinook.db not found -- kernel cwd: " + str(Path.cwd()))
db = SQLDatabase.from_uri(f"sqlite:///{_db}")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"
# Out:
# /tmp/ipykernel_1012/2549610831.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
#     443 The connection is instrumented such that when its
#    (...)    446
#     447 """
# --> 448 return _ConnectionFairy._checkout(self)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1271 if not fairy:
# -> 1272     fairy = _ConnectionRecord.checkout(pool)
#    1274     if threadconns is not None:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:176, in QueuePool._do_get(self)
#     175 try:
# --> 176     return self._create_connection()
#     177 except:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     387 """Called by subclasses to create a new ConnectionRecord."""
# --> 389 return _ConnectionRecord(self)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 3
#       1 from langchain_community.utilities import SQLDatabase
#       2
# ----> 3 db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")
#       4
#       5 @tool
#       6 def query_playlist_db(query: str) -> str:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_community/utilities/sql_database.py:180, in SQLDatabase.from_uri(cls, database_uri, engine_args, **kwargs)
#     178 """Construct a SQLAlchemy engine from URI."""
#     179 _engine_args = engine_args or {}
# --> 180 return cls(create_engine(database_uri, **_engine_args), **kwargs)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_community/utilities/sql_database.py:106, in SQLDatabase.__init__(self, engine, schema, metadata, ignore_tables, include_tables, sample_rows_in_table_info, indexes_in_table_info, custom_table_info, view_support, max_string_length, lazy_table_reflection)
#     103 if include_tables and ignore_tables:
#     104     raise ValueError("Cannot specify both include_tables and ignore_tables")
# --> 106 self._inspector = inspect(self._engine)
#     108 # including view support by adding the views as well as tables to the all
#     109 # tables list if view_support is True
#     110 self._all_tables = set(
#     111     list(self._inspector.get_table_names(schema=schema))
#     112     + (self._inspector.get_view_names(schema=schema) if view_support else [])
#    (...)    117     )
#     118 )
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/inspection.py:141, in inspect(subject, raiseerr)
#     139 elif reg is True:
#     140     return subject
# --> 141 ret = reg(subject)
#     142 if ret is not None:
#     143     return ret
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/reflection.py:314, in Inspector._engine_insp(bind)
#     312 @inspection._inspects(Engine)
#     313 def _engine_insp(bind: Engine) -> Inspector:  # type: ignore[misc]
# --> 314     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/reflection.py:247, in Inspector._construct(cls, init, bind)
#     244     cls = bind.dialect.inspector
#     246 self = cls.__new__(cls)
# --> 247 init(self, bind)
#     248 return self
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/reflection.py:258, in Inspector._init_engine(self, engine)
#     256 def _init_engine(self, engine: Engine) -> None:
#     257     self.bind = self.engine = engine
# --> 258     engine.connect().close()
#     259     self._op_context_requires_connect = True
#     260     self.dialect = self.engine.dialect
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3295, in Engine.connect(self)
#    3272 def connect(self) -> Connection:
#    3273     """Return a new :class:`_engine.Connection` object.
#    3274
#    3275     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3292
#    3293     """
# -> 3295     return self._connection_cls(self)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
# --> 146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#     149         raise
#     150 else:
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2450, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2448 elif should_wrap:
#    2449     assert sqlalchemy_exception is not None
# -> 2450     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2451 else:
#    2452     assert exc_info[1] is not None
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 if connection is None:
#     143     try:
# --> 144         self._dbapi_connection = engine.raw_connection()
#     145     except dialect.loaded_dbapi.Error as err:
#     146         Connection._handle_dbapi_exception_noconnection(
#     147             err, dialect, engine
#     148         )
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3319, in Engine.raw_connection(self)
#    3297 def raw_connection(self) -> PoolProxiedConnection:
#    3298     """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300     The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318     """
# -> 3319     return self.pool.connect()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:448, in Pool.connect(self)
#     440 def connect(self) -> PoolProxiedConnection:
#     441     """Return a DBAPI connection from the pool.
#     442
#     443     The connection is instrumented such that when its
#    (...)    446
#     447     """
# --> 448     return _ConnectionFairy._checkout(self)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1272, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1264 @classmethod
#    1265 def _checkout(
#    1266     cls,
#    (...)   1269     fairy: Optional[_ConnectionFairy] = None,
#    1270 ) -> _ConnectionFairy:
#    1271     if not fairy:
# -> 1272         fairy = _ConnectionRecord.checkout(pool)
#    1274         if threadconns is not None:
#    1275             threadconns.current = weakref.ref(fairy)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:178, in QueuePool._do_get(self)
#     176     return self._create_connection()
#     177 except:
# --> 178     with util.safe_reraise():
#     179         self._dec_overflow()
#     180     raise
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:176, in QueuePool._do_get(self)
#     174 if self._inc_overflow():
#     175     try:
# --> 176         return self._create_connection()
#     177     except:
#     178         with util.safe_reraise():
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:389, in Pool._create_connection(self)
#     386 def _create_connection(self) -> ConnectionPoolEntry:
#     387     """Called by subclasses to create a new ConnectionRecord."""
# --> 389     return _ConnectionRecord(self)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/create.py:667, in create_engine.<locals>.connect(connection_record)
#     665     return dialect.connect(*mutable_cargs, **mutable_cparams)
#     666 else:
# --> 667     return dialect.connect(*cargs_tup, **cparams)
#
# File ~/lca-lc-foundations/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:630, in DefaultDialect.connect(self, *cargs, **cparams)
#     628 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     629     # inherits the docstring from interfaces.Dialect.connect
# --> 630     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model=model,
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model=model,
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model=model,
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='baea10e5-c1df-4409-baa4-56a0976fcd2b'),
#               AIMessage(content=[], additional_kwargs={'function_call': {'name': 'update_state', 'arguments': '{"guest_count": "100", "genre": "jazz", "destination": "Paris", "origin": "London"}'}, '__gemini_function_call_thought_signatures__': {'call_829442': 'EnEKbwFpFH0TjDzRJsJk2BF8W1ADAAXyEII6p+iZOi8V4h3L8+Vf3XuEq8jK9Q3JnGdka0jAWZci8xU1UHTbvZ5QcSQDmEN2M+ycS1stBwXYwuIATwJO/pE/+b1NwbtIyyzeVp++mTtTQ4SIh1kiYXXidQ=='}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0d5f9-acf5-7143-a636-e3491ee02d74-0', tool_calls=[{'name': 'update_state', 'args': {'guest_count': '100', 'genre': 'jazz', 'destination': 'Paris', 'origin': 'London'}, 'id': 'call_829442', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 309, 'output_tokens': 38, 'total_tokens': 347, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='f128d367-312c-4e1f-a029-da21a494ac02', tool_call_id='call_829442'),
#               AIMessage(content=[], additional_kwargs={'function_call': {'name': 'suggest_playlist', 'arguments': '{"genre": "jazz"}'}, '__gemini_function_call_thought_signatures__': {'call_1260980': 'EnEKbwFpFH0TyGrBSefrZEZef/lrMeOrKPlDV7Umyfk3SIE7JGQbtn2/0JiE0XEsJjoHRiO/yZ0P+v9PWzA5JKlRE7HMKFfes5mcTBLGpNWCmllYkAcvFyf9xmrz2uobhGSOxw7bbN5SF7pMr20imcMkVg=='}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0d5f9-b5ba-7e82-a20a-f0300206f665-0', tool_calls=[{'name': 'search_flights', 'args': {'destination': 'Paris', 'origin': 'London'}, 'id': 'call_1260980', 'type': 'tool_call'}, {'name': 'search_venues', 'args': {'capacity': 100, 'location': 'Paris'}, 'id': 'call_1260981', 'type': 'tool_call'}, {'name': 'suggest_playlist', 'args': {'genre': 'jazz'}, 'id': 'call_1260982', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 363, 'output_tokens': 60, 'total_tokens': 423, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content=[{'type': 'text', 'text': 'For a destination wedding in Paris, early summer (mid-June) is a beautiful time to visit, with pleasant weather and the city in full bloom. Here are the best one-way flight options from London to Paris for June 15, 2027:\n\n### Flight Options (London to Paris)\n\n| Route | Times & Duration | Cabin | Price | Booking Link |\n| :--- | :--- | :--- | :--- | :--- |\n| **LTN → CDG** | 19:10 → 21:30 (1h 20m) | Economy | 64 EUR | [Book Now](https://kiwi.com/u/cfvfhg2) |\n| **LTN → CDG** | 07:05 → 09:30 (1h 25m) | Economy | 64 EUR | [Book Now](https://kiwi.com/u/xw4y7k) |\n| **LTN → CDG** | 12:30 → 14:55 (1h 25m) | Economy | 65 EUR | [Book Now](https://kiwi.com/u/cyuhr5) |\n| **LGW → CDG** | 17:00 → 19:15 (1h 15m) | Economy | 105 EUR | [Book Now](https://kiwi.com/u/x4vyr2) |\n| **LHR → CDG** | 19:45 → 22:00 (1h 15m) | Economy | 145 EUR | [Book Now](https://kiwi.com/u/jfgbtp) |\n\n### Summary\n*   **Cheapest Option:** The flights with **easyJet (U2)** from London Luton (LTN) to Paris Charles de Gaulle (CDG) are the most budget-friendly, starting at **64 EUR**.\n*   **Shortest Option:** Several flights, including those from London Gatwick (LGW) with Air France and London Heathrow (LHR) with Air France, offer a quick travel time of just **1 hour and 15 minutes**.\n\n**Recommendation:** If you are looking to minimize costs, the early morning or evening easyJet flights from Luton provide excellent value. If you prefer a major airport like Heathrow for better accessibility, the Air France option is a convenient, though slightly more expensive, choice.\n\nHave a wonderful trip! Did you know that Paris is known as the "City of Light" (*La Ville Lumière*)—not just because of its street lighting, but because it was one of the first cities in Europe to adopt gas street lighting in the 19th century?', 'extras': {'signature': 'EnEKbwFpFH0Tr/ajoUnq2p2tFAG0tN7YqxIMdsc0WfnduADUhEGIDS9WAGhy7DRaRjMgWiPZ8MlJqvIkMMSjtjYD4BpbIXRRXmkMjw5X4d/oK7SDJq3AdOiPaSBvE3PpNlVKdTMSLoREtm59Wl/vHmxdgQ=='}}], name='search_flights', id='ba125dbc-a271-4173-9769-219fd8d2f7ee', tool_call_id='call_1260980'),
#               ToolMessage(content=[{'type': 'text', 'text': 'Finding a wedding venue in Paris for exactly 100 guests involves navigating a wide range of pricing and prestige levels. Because most luxury venues in Paris (such as palace hotels) do not publish standardized, low-price rate cards, costs are primarily driven by in-house catering requirements and seasonal demand.\n\nBelow are top-rated venue options in Paris suitable for 100 guests, categorized by their style and general approach to hosting.\n\n### Highly-Rated Paris Venues (100-Guest Capacity)\n\n| Venue | Style | Note on Budget/Value |\n| :--- | :--- | :--- |\n| **Hôtel de Crillon** | Palace Hotel (Luxury) | Iconic location at Place de la Concorde. High-end, premium pricing. |\n| **Musée Rodin** | Historic Garden/Mansion | Highly prestigious. Best for those seeking an iconic Parisian atmosphere. |\n| **The Peninsula Paris** | Palace Hotel (Luxury) | Offers Eiffel Tower view terraces. Excellent service, high-end investment. |\n| **Hôtel Le Marois** | Classic Parisian Mansion | Offers a more traditional "private mansion" feel; often requires in-house catering. |\n| **Shangri-La Paris** | Palace Hotel (Luxury) | Renowned for views and elegance. High-tier pricing with mandatory in-house catering. |\n\n### Summary & Planning Guidance\n\n*   **Pricing Reality:** In Paris, a "lowest price" venue is relative. Venues that appear to have a lower "rental fee" (e.g., €5,000–€9,000) often mandate the use of their exclusive, high-end in-house catering teams. For 100 guests, you should realistically budget between **€40,000 and €100,000+** for the venue and catering combined, depending on the level of luxury.\n*   **The "100-Guest" Tier:** The venues listed above are specifically noted for their ability to handle the 100-guest capacity comfortably while maintaining high guest review scores for service and atmosphere.\n*   **Recommendation:** If you are seeking the best "value," look toward historic mansions or venues slightly outside the immediate city center (but still in the Île-de-France region), where you might have more flexibility to bring in external vendors, which can sometimes provide more control over the catering budget.\n*   **Important Note:** Prices in France usually exclude the mandatory 20% TVA (VAT). Always ask for a quote that includes taxes to avoid budget surprises.\n\nSince these venues are premium establishments, I recommend contacting their events teams directly to request a custom proposal for your specific date, as they rarely offer "standard" packages for 100-guest weddings.', 'extras': {'signature': 'EnEKbwFpFH0TUjpsO7DzPZab8O4VftyJ5CCNLvmQ5WpIj76/zpQJu7e8MWHwq7L3QaUn68+A3BPZdSheuvst0e+koHYi76MQ82Up5i38jAxIj0kY0rZrKJLh3Rs6QQwfeMx1EaYy0ZDlxshXRbuG+iqrKA=='}}], name='search_venues', id='ac0ac918-fba4-4df6-b013-93f9b3cca43d', tool_call_id='call_1260981'),
#               ToolMessage(content=[{'type': 'text', 'text': "Here is a curated Jazz wedding playlist for your special day.\n\n### Wedding Jazz Playlist\n\n| Track Name | Duration (min) | Price |\n| :--- | :--- | :--- |\n| Pretinha | 4.42 | $0.99 |\n| Outra Vez | 2.11 | $0.99 |\n| It Doesn't Matter | 4.50 | $0.99 |\n| Lemon Drop | 3.23 | $0.99 |\n| Springsville (Alternate Take) | 3.27 | $0.99 |\n| Desafinado | 3.09 | $0.99 |\n| Sunchild | 4.33 | $0.99 |\n| The Maids Of Cadiz | 3.90 | $0.99 |\n| Best Thing | 4.57 | $0.99 |\n| Midget | 3.62 | $0.99 |\n\n***\n\n**Playlist Summary:**\n*   **Total Duration:** Approximately 35 minutes and 32 seconds (2,222,414 milliseconds)\n*   **Total Cost:** $9.90", 'extras': {'signature': 'EnEKbwFpFH0T+Z/4uI6bcJ1htgPsinHKBISfSkvDFSf2VpNgTgEYX3zrU5cH6TZPH+bb8uLt9Ghh4n+H1DmI9KkzYrI+HzY+M7EOC29++TPjWLfGcC3BlDpSKtpkMqe8nJjT0W+c/zPzrn7WZh6puhw80g=='}}], name='suggest_playlist', id='8840d20e-0b50-4de0-a5d1-35da4788f623', tool_call_id='call_1260982'),
#               AIMessage(content=[{'type': 'text', 'text': 'It sounds like you are planning a truly magical wedding! Paris is the perfect choice for a romantic, jazz-themed celebration. Based on your preferences for 100 guests, I have coordinated the following details for you:\n\n### **Flights from London to Paris**\nFor your 100 guests, you have excellent options from London.\n*   **Most Economical:** EasyJet from **London Luton (LTN)** to Paris Charles de Gaulle (CDG) starts at approximately **64 EUR** per person.\n*   **Convenience:** For those preferring major hubs, Air France flies from **Heathrow (LHR)** to Paris with a flight time of just 1 hour and 15 minutes (starting at 145 EUR).\n\n### **Venue Selection**\nHosting 100 guests in Paris opens up some of the most beautiful historic venues in the world. Given the scale of your wedding, I recommend considering these top-tier options:\n*   **Hôtel de Crillon** or **The Peninsula Paris:** Ideal if you want a classic, luxury hotel experience with iconic views.\n*   **Musée Rodin:** A stunning choice if you are looking for a unique, historic, and prestigious atmosphere.\n*   **Note on Budget:** For 100 guests at this caliber, you should realistically budget between €40,000 and €100,000+ for venue and catering. Please ensure you ask for quotes inclusive of the 20% French VAT (TVA).\n\n### **Your Jazz Playlist**\nI have curated a 35-minute jazz playlist featuring classics and smooth tracks to set the perfect mood for your ceremony or reception.\n*   **Featured Tracks:** Includes *Pretinha*, *Desafinado*, and *Lemon Drop*, among others.\n*   **Cost:** The total cost for the music selection is $9.90.\n\n**Next Steps for You:**\n1.  **Dates:** Since I have provided general availability, you should now pick a specific date and reach out to your preferred venue(s) to confirm availability and request a custom proposal.\n2.  **Catering:** Once you select a venue, clarify their catering requirements, as many Parisian venues have exclusive vendors.\n3.  **Group Travel:** Since you have 100 guests, I recommend contacting an airline group travel desk to secure a block of seats for your guests, which may provide better rates and flexibility than individual bookings.\n\nDoes this plan sound good, or would you like me to refine any of these options?', 'extras': {'signature': 'EnEKbwFpFH0T8l2JaIW2cCqzDFpSbyhANVSld8i8LtSY1eRJhojge5tBVyH8xXNrYs+l0fsG7owuFPih4N6hmulx6MbpV3ydzxMz6YUFTadXWUl1+lwzwIoSd1NSqTb6GuI6SX0FazXDCd927ywhYT3f6g=='}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0d5f9-e9f3-7721-bb6b-04367f6012bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2302, 'output_tokens': 541, 'total_tokens': 2843, 'input_token_details': {'cache_read': 0}})],
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'It sounds like you are planning a truly magical wedding! Paris is the perfect choice for a romantic, jazz-themed celebration. Based on your preferences for 100 guests, I have coordinated the following details for you:\n\n### **Flights from London to Paris**\nFor your 100 guests, you have excellent options from London.\n*   **Most Economical:** EasyJet from **London Luton (LTN)** to Paris Charles de Gaulle (CDG) starts at approximately **64 EUR** per person.\n*   **Convenience:** For those preferring major hubs, Air France flies from **Heathrow (LHR)** to Paris with a flight time of just 1 hour and 15 minutes (starting at 145 EUR).\n\n### **Venue Selection**\nHosting 100 guests in Paris opens up some of the most beautiful historic venues in the world. Given the scale of your wedding, I recommend considering these top-tier options:\n*   **Hôtel de Crillon** or **The Peninsula Paris:** Ideal if you want a classic, luxury hotel experience with iconic views.\n*   **Musée Rodin:** A stunning choice if you are looking for a unique, historic, and prestigious atmosphere.\n*   **Note on Budget:** For 100 guests at this caliber, you should realistically budget between €40,000 and €100,000+ for venue and catering. Please ensure you ask for quotes inclusive of the 20% French VAT (TVA).\n\n### **Your Jazz Playlist**\nI have curated a 35-minute jazz playlist featuring classics and smooth tracks to set the perfect mood for your ceremony or reception.\n*   **Featured Tracks:** Includes *Pretinha*, *Desafinado*, and *Lemon Drop*, among others.\n*   **Cost:** The total cost for the music selection is $9.90.\n\n**Next Steps for You:**\n1.  **Dates:** Since I have provided general availability, you should now pick a specific date and reach out to your preferred venue(s) to confirm availability and request a custom proposal.\n2.  **Catering:** Once you select a venue, clarify their catering requirements, as many Parisian venues have exclusive vendors.\n3.  **Group Travel:** Since you have 100 guests, I recommend contacting an airline group travel desk to secure a block of seats for your guests, which may provide better rates and flexibility than individual bookings.\n\nDoes this plan sound good, or would you like me to refine any of these options?', 'extras': {'signature': 'EnEKbwFpFH0T8l2JaIW2cCqzDFpSbyhANVSld8i8LtSY1eRJhojge5tBVyH8xXNrYs+l0fsG7owuFPih4N6hmulx6MbpV3ydzxMz6YUFTadXWUl1+lwzwIoSd1NSqTb6GuI6SX0FazXDCd927ywhYT3f6g=='}}]

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
